# %% [markdown]
# # Naive Bayes Classifier from scratch

# %%
from math import exp, pi, sqrt
from sklearn.model_selection import train_test_split
from scipy.stats import norm
from math import log
import numpy as np
import pandas as pd

# %%
raw_data = pd.read_csv('Development Index.csv')
raw_data
# Out:
#      Population  Area (sq. mi.)  Pop. Density   GDP ($ per capita)  \
# 0       9944201         1284000            7.7                1200
# 1       5450661           43094          126.5               31100
# 2      26783383          437072           61.3                1500
# 3          9439             102           92.5                3400
# 4       3431932          176220           19.5               12800
# ..          ...             ...            ...                 ...
# 220    74777981         1127127           66.3                 700
# 221      474413            2586          183.5               55100
# 222     1065842            5128          207.9                9500
# 223     3042004          111370           27.3                1000
# 224    22409572          239460           93.6                2200
#
#      Literacy (%)  Infant mortality   Development Index
# 0            47.5              93.82                  2
# 1           100.0               4.56                  4
# 2            40.4              50.25                  2
# 3            97.0               7.35                  4
# 4            98.0              11.95                  3
# ..            ...                ...                ...
# 220          42.7              95.32                  2
# 221         100.0               4.81                  4
# 222          98.6              24.31                  3
# 223          57.5             128.87                  1
# 224          74.8              51.43                  2
#
# [225 rows x 7 columns]

# %%
raw_data.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density   GDP ($ per capita)  \
# count  2.250000e+02    2.250000e+02     225.000000          225.000000
# mean   2.898360e+07    6.023363e+05     380.545778         9729.333333
# std    1.183879e+08    1.797679e+06    1667.386671        10053.936329
# min    7.026000e+03    2.000000e+00       0.000000          500.000000
# 25%    4.391170e+05    4.167000e+03      29.300000         1900.000000
# 50%    5.042920e+06    8.660000e+04      78.800000         5600.000000
# 75%    1.765484e+07    4.465500e+05     188.500000        15700.000000
# max    1.313974e+09    1.707520e+07   16271.500000        55100.000000
#
#        Literacy (%)  Infant mortality   Development Index
# count    225.000000         225.000000         225.000000
# mean      83.987556          35.261956           2.968889
# std       19.455371          35.453113           0.883333
# min       17.600000           0.000000           1.000000
# 25%       76.200000           7.870000           2.000000
# 50%       93.000000          20.970000           3.000000
# 75%       98.500000          55.510000           4.000000
# max      100.000000         191.190000           4.000000

# %% [markdown]
# ## Drop unnecessary column

# %%
df = raw_data.drop(columns=['Pop. Density '])
df
# Out:
#      Population  Area (sq. mi.)  GDP ($ per capita)  Literacy (%)  \
# 0       9944201         1284000                1200          47.5
# 1       5450661           43094               31100         100.0
# 2      26783383          437072                1500          40.4
# 3          9439             102                3400          97.0
# 4       3431932          176220               12800          98.0
# ..          ...             ...                 ...           ...
# 220    74777981         1127127                 700          42.7
# 221      474413            2586               55100         100.0
# 222     1065842            5128                9500          98.6
# 223     3042004          111370                1000          57.5
# 224    22409572          239460                2200          74.8
#
#      Infant mortality   Development Index
# 0                93.82                  2
# 1                 4.56                  4
# 2                50.25                  2
# 3                 7.35                  4
# 4                11.95                  3
# ..                 ...                ...
# 220              95.32                  2
# 221               4.81                  4
# 222              24.31                  3
# 223             128.87                  1
# 224              51.43                  2
#
# [225 rows x 6 columns]

# %%
df = df.astype('float32')

# %%
df.dtypes
# Out:
# Population            float32
# Area (sq. mi.)        float32
# GDP ($ per capita)    float32
# Literacy (%)          float32
# Infant mortality      float32
# Development Index     float32
# dtype: object

# %% [markdown]
# ## Sort the data into classes

# %%
y_true = df.iloc[:, -1:]
y_true
# Out:
#      Development Index
# 0                  2.0
# 1                  4.0
# 2                  2.0
# 3                  4.0
# 4                  3.0
# ..                 ...
# 220                2.0
# 221                4.0
# 222                3.0
# 223                1.0
# 224                2.0
#
# [225 rows x 1 columns]

# %%
y_true.value_counts()
# Out:
# Development Index
# 3.0                  89
# 4.0                  71
# 2.0                  52
# 1.0                  13
# dtype: int64

# %% [markdown]
# ## Split the training and test sets

# %%
df.iloc[:, :-1], df.iloc[:, -1]
# Out:
# (     Population  Area (sq. mi.)  GDP ($ per capita)  Literacy (%)  \
#  0     9944201.0       1284000.0              1200.0     47.500000
#  1     5450661.0         43094.0             31100.0    100.000000
#  2    26783384.0        437072.0              1500.0     40.400002
#  3        9439.0           102.0              3400.0     97.000000
#  4     3431932.0        176220.0             12800.0     98.000000
#  ..          ...             ...                 ...           ...
#  220  74777984.0       1127127.0               700.0     42.700001
#  221    474413.0          2586.0             55100.0    100.000000
#  222   1065842.0          5128.0              9500.0     98.599998
#  223   3042004.0        111370.0              1000.0     57.500000
#  224  22409572.0        239460.0              2200.0     74.800003
#
#       Infant mortality
#  0            93.820000
#  1             4.560000
#  2            50.250000
#  3             7.350000
#  4            11.950000
#  ..                 ...
#  220          95.320000
#  221           4.810000
#  222          24.309999
#  223         128.869995
#  224          51.430000
#
#  [225 rows x 5 columns],
#  0      2.0
#  1      4.0
#  2      2.0
#  3      4.0
#  4      3.0
#        ...
#  220    2.0
#  221    4.0
#  222    3.0
#  223    1.0
#  224    2.0
#  Name: Development Index, Length: 225, dtype: float32)

# %%
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:], df.iloc[:, -1], test_size=0.2, random_state=0)

# %%
X_train
# Out:
#       Population  Area (sq. mi.)  GDP ($ per capita)  Literacy (%)  \
# 212     439117.0        163270.0              4000.0     93.000000
# 33      221736.0           960.0             11400.0     96.699997
# 170      33987.0           160.0             25000.0    100.000000
# 83    10235455.0         78866.0             15700.0     99.900002
# 201     452776.0          1780.0              8000.0     90.000000
# ..           ...             ...                 ...           ...
# 67   188078224.0       8511965.0              7600.0     86.400002
# 192   27307134.0        447400.0              1700.0     99.300003
# 117      13287.0            21.0              5000.0     99.000000
# 47   127463608.0        377835.0             28200.0     99.000000
# 172    4303356.0        622984.0              1100.0     51.000000
#
#      Infant mortality   Development Index
# 212          23.570000                3.0
# 33           10.030000                3.0
# 170           4.700000                4.0
# 83            3.930000                4.0
# 201           8.600000                4.0
# ..                 ...                ...
# 67           29.610001                3.0
# 192          71.099998                2.0
# 117           9.950000                4.0
# 47            3.260000                4.0
# 172          91.000000                2.0
#
# [180 rows x 6 columns]

# %%
Xy1 = X_train.loc[(X_train["Development Index"] == 1)]
Xy2 = X_train.loc[(X_train["Development Index"] == 2)]
Xy3 = X_train.loc[(X_train["Development Index"] == 3)]
Xy4 = X_train.loc[(X_train["Development Index"] == 4)]
Xy1.shape, Xy2.shape, Xy3.shape, Xy4.shape
# Out:
# ((9, 6), (42, 6), (68, 6), (61, 6))

# %% [markdown]
# ## Calculate Priors

# %%
def fit_distribution(data):
    mean = data.mean()
    sigma = data.std()
    print("Mean:", mean, "Sigma:", sigma)
    dist = norm(mean, sigma)
    return dist

# %%
priory1 = len(Xy1) / len(X_train)
priory2 = len(Xy2) / len(X_train)
priory3 = len(Xy3) / len(X_train)
priory4 = len(Xy4) / len(X_train)
priory1, priory2, priory3, priory4
# Out:
# (0.05, 0.23333333333333334, 0.37777777777777777, 0.3388888888888889)

# %%
# Create PDF HDI == 1
X1y1 = fit_distribution(Xy1.iloc[:, 0])
X2y1 = fit_distribution(Xy1.iloc[:, 1])
X3y1 = fit_distribution(Xy1.iloc[:, 2])
X4y1 = fit_distribution(Xy1.iloc[:, 3])
X5y1 = fit_distribution(Xy1.iloc[:, 4])
print()

# Create PDF HDI == 2
X1y2 = fit_distribution(Xy2.iloc[:, 0])
X2y2 = fit_distribution(Xy2.iloc[:, 1])
X3y2 = fit_distribution(Xy2.iloc[:, 2])
X4y2 = fit_distribution(Xy2.iloc[:, 3])
X5y2 = fit_distribution(Xy2.iloc[:, 4])
print()

# Create PDF HDI == 3
X1y3 = fit_distribution(Xy3.iloc[:, 0])
X2y3 = fit_distribution(Xy3.iloc[:, 1])
X3y3 = fit_distribution(Xy3.iloc[:, 2])
X4y3 = fit_distribution(Xy3.iloc[:, 3])
X5y3 = fit_distribution(Xy3.iloc[:, 4])
print()

# Create PDF HDI == 4
X1y4 = fit_distribution(Xy4.iloc[:, 0])
X2y4 = fit_distribution(Xy4.iloc[:, 1])
X3y4 = fit_distribution(Xy4.iloc[:, 2])
X4y4 = fit_distribution(Xy4.iloc[:, 3])
X5y4 = fit_distribution(Xy4.iloc[:, 4])
print()
# Out:
# Mean: 9840249.0 Sigma: 9304303.0
# Mean: 462174.12 Sigma: 511906.9
# Mean: 900.0 Sigma: 452.76926
# Mean: 43.922222 Sigma: 16.077219
# Mean: 131.08667 Sigma: 29.922348
#
# Mean: 44148460.0 Sigma: 168546820.0
# Mean: 547294.4 Sigma: 680784.25
# Mean: 2197.6191 Sigma: 1830.4321
# Mean: 66.38094 Sigma: 21.008015
# Mean: 71.46644 Sigma: 14.415833
#
# Mean: 38962436.0 Sigma: 162323230.0
# Mean: 609764.6 Sigma: 1618710.6
# Mean: 6247.0586 Sigma: 4383.295
# Mean: 89.27795 Sigma: 11.173808
# Mean: 24.581175 Sigma: 9.597111
#
# Mean: 16897094.0 Sigma: 43395668.0
# Mean: 534781.44 Sigma: 1983192.5
# Mean: 20572.13 Sigma: 10259.372
# Mean: 96.54918 Sigma: 6.8243833
# Mean: 5.986886 Sigma: 2.2562215

# %%
def probability(X, prior, dists):
    prob = prior
    idx = 0
    for dist in dists:
        tmp = dist.pdf(X[idx])
        if tmp <= 0:
            tmp = 0.1
        res = log(tmp)
        
        prob = prob + res
        idx = idx + 1
    
    return prob

# %%
print(probability([9944201, 1284000, 1200, 47.5, 93.82], priory1, [X1y1, X2y1, X3y1, X4y1 ,X5y1]))
print(probability([9944201, 1284000, 1200, 47.5, 93.82], priory2, [X1y2, X2y2, X3y2, X4y2 ,X5y2]))
print(probability([9944201, 1284000, 1200, 47.5, 93.82], priory3, [X1y3, X2y3, X3y3, X4y3 ,X5y3]))
print(probability([9944201, 1284000, 1200, 47.5, 93.82], priory4, [X1y4, X2y4, X3y4, X4y4 ,X5y4]))
# Out:
# -48.33656133445865
# -52.32134841027359
# -84.25997819141132
# -76.57784935623623

# %%
def predict(data):
    category_ls = []
    category_ls.append(probability(data, priory1, [X1y1, X2y1, X3y1, X4y1 ,X5y1]))
    category_ls.append(probability(data, priory2, [X1y2, X2y2, X3y2, X4y2 ,X5y2]))
    category_ls.append(probability(data, priory3, [X1y3, X2y3, X3y3, X4y3 ,X5y3]))
    category_ls.append(probability(data, priory4, [X1y4, X2y4, X3y4, X4y4 ,X5y4]))
    
    maximum = np.argmax(category_ls)
    return maximum + 1

# %%
predict([9944201, 1284000, 1200, 47.5, 93.82])
# Out:
# 1

# %%
row1 = df.iloc[17]
row1
# Out:
# Population            2.828715e+07
# Area (sq. mi.)        1.471810e+05
# GDP ($ per capita)    1.400000e+03
# Literacy (%)          4.520000e+01
# Infant mortality      6.698000e+01
# Development Index     2.000000e+00
# Name: 17, dtype: float32

# %%
row = df.iloc[17, :-1]
row.to_numpy()
# Out:
# array([2.8287148e+07, 1.4718100e+05, 1.4000000e+03, 4.5200001e+01,
#        6.6980003e+01], dtype=float32)

# %%
predict(row)
# Out:
# 2

# %% [markdown]
# ## Prepare to test and evaluate

# %%
y_true = X_test.iloc[:, -1]
X_test, y_true
# Out:
# (      Population  Area (sq. mi.)  GDP ($ per capita)  Literacy (%)  \
#  111  107449528.0       1972550.0              9000.0     92.199997
#  101  147365344.0        144000.0              1900.0     43.099998
#  197      56361.0       2166086.0             20000.0     99.000000
#  183  142893536.0      17075200.0              8900.0     99.599998
#  75     8192880.0         83870.0             30000.0     98.000000
#  64    10293011.0        207600.0              6100.0     99.599998
#  145   18881360.0        185180.0              3300.0     76.900002
#  137    2602713.0         82880.0             23200.0     77.900002
#  207    7862944.0        112620.0              1100.0     40.900002
#  168    4610820.0        323802.0             37800.0    100.000000
#  143      89703.0           344.0              5000.0     98.000000
#  166    2279723.0         47000.0              1300.0     42.200001
#  107     905949.0         18270.0              5800.0     93.699997
#  8       453125.0            28.0             19400.0     94.500000
#  126     108605.0          1910.0             17200.0     99.000000
#  156   19686504.0        801590.0              1200.0     47.799999
#  108     199509.0         91000.0              8300.0     83.000000
#  5      2050554.0         25333.0              6700.0     99.000000
#  44   131859728.0        923768.0               900.0     68.000000
#  139   24385858.0        329750.0              9000.0     88.699997
#  176   28195754.0        236040.0              1400.0     69.900002
#  153    3874050.0         10400.0              4800.0     87.400002
#  187    3702314.0        342000.0               700.0     83.800003
#  179     420979.0          4033.0              1400.0     76.599998
#  106      81541.0           455.0              7800.0     58.000000
#  125    6368481.0        236800.0              1700.0     66.400002
#  97     1639833.0        600370.0              9000.0     79.800003
#  37     1428757.0           360.0               600.0     99.000000
#  12    28302604.0       1285220.0              5100.0     90.900002
#  202      60422.0         11854.0              1600.0     93.699997
#  161   13881427.0        181040.0              1900.0     69.400002
#  134     379444.0          5770.0             18600.0     93.900002
#  104      71201.0           468.0             19000.0    100.000000
#  55     7320815.0        143100.0              1000.0     99.400002
#  89     2976372.0         29800.0              3500.0     98.599998
#  18       82459.0           477.0             12500.0     97.000000
#  15    40397840.0        504782.0             22000.0     97.900002
#  149   27019732.0       1960582.0             11800.0     78.800003
#  7        47246.0          1399.0             22000.0     99.000000
#  159    3581655.0         28748.0              4500.0     86.500000
#  178   17340702.0        475440.0              1800.0     79.000000
#  90    62660552.0       2345410.0               700.0     65.500000
#  144      71891.0           193.0             28000.0     97.000000
#  92    11716829.0       1240000.0               900.0     46.400002
#  63     4494749.0         56542.0             10600.0     98.500000
#
#       Infant mortality   Development Index
#  111          20.910000                3.0
#  101          62.599998                2.0
#  197          15.820000                3.0
#  183          15.390000                3.0
#  75            4.660000                4.0
#  64           13.370000                3.0
#  145          29.530001                3.0
#  137          14.510000                3.0
#  207          85.000000                2.0
#  168           3.700000                4.0
#  143          14.620000                3.0
#  166         100.440002                1.0
#  107          12.620000                3.0
#  8             4.390000                4.0
#  126           8.030000                4.0
#  156         130.789993                1.0
#  108          12.070000                3.0
#  5            10.090000                3.0
#  44           98.800003                2.0
#  139          17.700001                3.0
#  176          67.830002                2.0
#  153          24.520000                3.0
#  187          93.860001                2.0
#  179          47.770000                3.0
#  106          15.530000                3.0
#  125          85.220001                2.0
#  97           54.580002                2.0
#  37           22.930000                3.0
#  12           31.940001                3.0
#  202          29.450001                3.0
#  161          71.480003                2.0
#  134          12.610000                3.0
#  104           4.050000                4.0
#  55          110.760002                1.0
#  89           23.280001                3.0
#  18            7.110000                4.0
#  15            4.420000                4.0
#  149          13.240000                3.0
#  7             6.240000                4.0
#  159          21.520000                3.0
#  178          68.260002                2.0
#  90           94.690002                2.0
#  144           5.890000                4.0
#  92          116.790001                1.0
#  63            6.840000                4.0  ,
#  111    3.0
#  101    2.0
#  197    3.0
#  183    3.0
#  75     4.0
#  64     3.0
#  145    3.0
#  137    3.0
#  207    2.0
#  168    4.0
#  143    3.0
#  166    1.0
#  107    3.0
#  8      4.0
#  126    4.0
#  156    1.0
#  108    3.0
#  5      3.0
#  44     2.0
#  139    3.0
#  176    2.0
#  153    3.0
#  187    2.0
#  179    3.0
#  106    3.0
#  125    2.0
#  97     2.0
#  37     3.0
#  12     3.0
#  202    3.0
#  161    2.0
#  134    3.0
#  104    4.0
#  55     1.0
#  89     3.0
#  18     4.0
#  15     4.0
#  149    3.0
#  7      4.0
#  159    3.0
#  178    2.0
#  90     2.0
#  144    4.0
#  92     1.0
#  63     4.0
#  Name: Development Index, dtype: float32)

# %%
res = [predict(x) for x in X_test.iloc[:, :-1].to_numpy()]
res_np = np.array(res)
res_np, len(res_np)
# Out:
# (array([3, 2, 3, 4, 4, 3, 3, 1, 1, 4, 3, 1, 3, 4, 4, 1, 3, 4, 2, 3, 2, 3,
#         1, 2, 3, 1, 3, 3, 3, 3, 2, 4, 4, 4, 3, 4, 4, 3, 4, 3, 2, 2, 4, 1,
#         4], dtype=int64),
#  45)

# %%
y_true_np = y_true.to_numpy()
y_true_np = y_true_np.astype('int64')
y_true_np, len(y_true)
# Out:
# (array([3, 2, 3, 3, 4, 3, 3, 3, 2, 4, 3, 1, 3, 4, 4, 1, 3, 3, 2, 3, 2, 3,
#         2, 3, 3, 2, 2, 3, 3, 3, 2, 3, 4, 1, 3, 4, 4, 3, 4, 3, 2, 2, 4, 1,
#         4], dtype=int64),
#  45)

# %%
from sklearn.metrics import classification_report
target_names = ['1', '2', '3', '4']

print(classification_report(y_true_np, res_np, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.43      0.75      0.55         4
#            2       0.86      0.60      0.71        10
#            3       0.94      0.76      0.84        21
#            4       0.71      1.00      0.83        10
#
#     accuracy                           0.78        45
#    macro avg       0.74      0.78      0.73        45
# weighted avg       0.83      0.78      0.78        45

# %%
correct = 0
incorrect = 0
idx = 0
for item in y_true_np:
    if item == res_np[idx]:
        correct += 1
    else:
        incorrect += 1
    idx += 1

print("Correct:", correct, "Incorrect:", incorrect, "Total:", correct + incorrect)
# Out:
# Correct: 35 Incorrect: 10 Total: 45
